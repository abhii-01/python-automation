# %% [markdown]
# # Example Automation Task
#
# This is a template notebook for automation tasks. Replace this with your specific automation needs.

# %%
# Import necessary libraries
import pandas as pd
import os
from datetime import datetime

print("Environment setup complete!")
print(f"Current time: {datetime.now()}")

# %% [markdown]
# ## Task 1: Example Data Processing
#
# Add your automation logic here.

# %%
# Example: Create a sample dataframe
data = {
    'task': ['Task 1', 'Task 2', 'Task 3'],
    'status': ['Complete', 'In Progress', 'Pending'],
    'date': [datetime.now() for _ in range(3)]
}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ## Task 2: Save Results
#
# Export processed data.

# %%
# Save to data directory
output_path = '../data/example_output.csv'
# df.to_csv(output_path, index=False)
# print(f"Data saved to {output_path}")
